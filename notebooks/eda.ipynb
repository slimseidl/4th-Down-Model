# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\jseidl\\NFL-4th-Down\\data\\playbyplay_last_14_years.csv",low_memory=False)

# %%
df.head()
# Out:
#    play_id          game_id   old_game_id home_team away_team season_type  \
# 0      1.0  2010_01_ARI_STL  2.010091e+09        LA       ARI         REG
# 1     36.0  2010_01_ARI_STL  2.010091e+09        LA       ARI         REG
# 2     58.0  2010_01_ARI_STL  2.010091e+09        LA       ARI         REG
# 3     82.0  2010_01_ARI_STL  2.010091e+09        LA       ARI         REG
# 4    103.0  2010_01_ARI_STL  2.010091e+09        LA       ARI         REG
#
#    week posteam posteam_type defteam  ... offense_players  defense_players  \
# 0     1     NaN          NaN     NaN  ...             NaN              NaN
# 1     1     ARI         away      LA  ...             NaN              NaN
# 2     1     ARI         away      LA  ...             NaN              NaN
# 3     1     ARI         away      LA  ...             NaN              NaN
# 4     1     ARI         away      LA  ...             NaN              NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 672072 entries, 0 to 672071
# Columns: 392 entries, play_id to defense_coverage_type
# dtypes: float64(212), int64(9), object(171)
# memory usage: 2.0+ GB

# %%
df.describe()
# Out:
#              play_id   old_game_id           week   yardline_100  \
# count  672072.000000  2.860830e+05  672072.000000  625654.000000
# mean     2127.248365  2.012684e+09       9.555539      49.411370
# std      1247.266745  1.712987e+06       5.365950      24.805277
# min         1.000000  2.010091e+09       1.000000       1.000000
# 25%      1051.000000  2.011111e+09       5.000000      31.000000
# 50%      2115.000000  2.013091e+09      10.000000      51.000000
# 75%      3170.000000  2.014111e+09      14.000000      71.000000
# max      5921.000000  2.016021e+09      22.000000      99.000000
#
#        quarter_seconds_remaining  half_seconds_remaining  \
# count              671501.000000           671501.000000
# mean                  414.489670              815.003147
# std                   281.902296              558.399165
# min                     0.000000                0.000000
# 25%                   152.000000              289.000000
# ...

# %%
pd.set_option('display.max_columns', None)
list(df.columns)
# Out:
# ['play_id',
#  'game_id',
#  'old_game_id',
#  'home_team',
#  'away_team',
#  'season_type',
#  'week',
#  'posteam',
#  'posteam_type',
#  'defteam',
#  'side_of_field',
#  'yardline_100',
#  'game_date',
#  'quarter_seconds_remaining',
#  'half_seconds_remaining',
#  'game_seconds_remaining',
#  'game_half',
#  'quarter_end',
#  'drive',
#  'sp',
#  'qtr',
#  'down',
#  'goal_to_go',
#  'time',
#  'yrdln',
#  'ydstogo',
#  'ydsnet',
#  'desc',
#  'play_type',
#  'yards_gained',
#  'shotgun',
#  'no_huddle',
#  'qb_dropback',
#  'qb_kneel',
#  'qb_spike',
#  'qb_scramble',
#  'pass_length',
#  'pass_location',
#  'air_yards',
#  'yards_after_catch',
#  'run_location',
#  'run_gap',
#  'field_goal_result',
#  'kick_distance',
#  'extra_point_result',
#  'two_point_conv_result',
#  'home_timeouts_remaining',
#  'away_timeouts_remaining',
#  'timeout',
#  'timeout_team',
#  'td_team',
#  'td_player_name',
#  'td_player_id',
#  'posteam_timeouts_remaining',
# ...

# %%
df_4th = df[
    (df["down"] == 4) &
    (df["play_type"].isin(["run", "pass", "punt", "field_goal"])) &
    (df["season_type"] == "REG") &
    (df["epa"].notnull()) &
    (df["yardline_100"].notnull()) &
    (df["ydstogo"].notnull())
]

# %%
columns_to_keep = [
    "game_id",
    "play_id",
    "season",
    "week",
    "game_date",
    "qtr",
    "posteam",
    "defteam",
    "down",
    "ydstogo",
    "yardline_100",
    "goal_to_go",
    "play_type",
    "game_seconds_remaining",
    "half_seconds_remaining",
    "quarter_seconds_remaining",
    "game_half",
    "score_differential",
    "yards_gained",
    "epa",
    "success",
    "play_type",
    "posteam_timeouts_remaining",
    "defteam_timeouts_remaining",
    "wp",
    "def_wp",
    "home_wp",
    "away_wp",
    "wpa",
    "field_goal_result",
    "kick_distance",
    "punt_blocked",
    "no_huddle",
    "shotgun",
    "qb_dropback",
    "desc",
]

# %%
df_4th = df_4th[columns_to_keep]

# %%
df_4th.head()
# Out:
#             game_id  play_id  season  week   game_date  qtr posteam defteam  \
# 14  2010_01_ARI_STL    350.0    2010     1  2010-09-12  1.0      LA     ARI
# 18  2010_01_ARI_STL    445.0    2010     1  2010-09-12  1.0     ARI      LA
# 26  2010_01_ARI_STL    644.0    2010     1  2010-09-12  1.0     ARI      LA
# 30  2010_01_ARI_STL    727.0    2010     1  2010-09-12  1.0      LA     ARI
# 42  2010_01_ARI_STL   1018.0    2010     1  2010-09-12  2.0     ARI      LA
#
#     down  ydstogo  yardline_100  goal_to_go   play_type  \
# 14   4.0      7.0          16.0           0  field_goal
# 18   4.0     10.0          57.0           0        punt
# 26   4.0     10.0          39.0           0        punt
# 30   4.0      3.0          83.0           0        punt
# 42   4.0      3.0           4.0           0  field_goal
#
#     game_seconds_remaining  half_seconds_remaining  quarter_seconds_remaining  \
# 14                  3281.0                  1481.0                      581.0
# ...

# %%
import matplotlib.pyplot as plt

# %%
print(df_4th.columns[df_4th.columns.duplicated()])
# Out:
# Index(['play_type'], dtype='object')

# %%
df_4th = df_4th.loc[:, ~df_4th.columns.duplicated()]

# %%
# Only plays where team goes for it on 4th
conversion_attemps = df_4th[df_4th["play_type"].isin(["run", "pass"])]

# Clean and Sort
conversion_rate = (
    conversion_attemps.groupby("ydstogo")["success"]
    .mean()
    .reset_index()
    .sort_values("ydstogo")
)

# Casting yds to go as integer
conversion_rate["ydstogo"] = conversion_rate["ydstogo"].astype(int)

# Plot with matplotlib
plt.figure(figsize=(10, 6))
plt.bar(conversion_rate["ydstogo"], conversion_rate["success"])
plt.title("4th Down Conversion Rate by Yards to Go")
plt.xlabel("Yards to Go")
plt.ylabel("Conversion Rate")
plt.xticks(conversion_rate["ydstogo"])
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

# %%
epa_by_type = df_4th.groupby("play_type")["epa"].mean()
epa_by_type.plot(kind="bar", title="Average EPA by 4th Down Play Type")
# Out:
# <Axes: title={'center': 'Average EPA by 4th Down Play Type'}, xlabel='play_type'>

# %%
# Binning Field Position into 10-yard chunks
df_4th["yard_bin"] = pd.cut(df_4th["yardline_100"], bins=range(0, 110, 10))

#Comparing average EPA by type and position on field
epa_by_position = df_4th.groupby(["yard_bin", "play_type"])["epa"].mean().unstack()

# Visualizing
epa_by_position.plot(kind="line", title="EPA by Field Position and Play Type")
# Out:
# <Axes: title={'center': 'EPA by Field Position and Play Type'}, xlabel='yard_bin'>
